# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
num = 10000
N = 12
T=1

# %%
def gen_stockprices(S0 = 50, sigma = 0.2, T=1/N, mu = 0.1):
    S1 = S0*np.exp((mu - 0.5*sigma**2) * T + (sigma*np.sqrt(T)*np.random.normal(loc=0,scale=1)))
    return S1

# %%
prices = np.zeros((num,N+1))
for i in range(num):
    prices[i][0] = 50
    for j in range(N+1):
        if j == 0:
            continue
        prices[i][j] = gen_stockprices(S0 = prices[i][j-1])
prices[0]
# Out:
# array([50.        , 53.17978697, 54.70048938, 52.50850273, 55.25669026,
#        47.93091991, 46.97668371, 54.35752414, 49.19253762, 47.66991921,
#        44.73146773, 43.42684365, 39.83195458])

# %%
t = np.linspace(0,T,N+1)
# print(t.shape)
# print(prices[0].shape)
plt.figure(figsize=(5, 5))
for i in range(num):
    plt.plot(t,prices[i])
plt.axhline(y = 35)
plt.title('Monte Carlo Simulation of Stock Prices')
plt.xlabel('Time (Months)')
plt.ylabel('Stock Price')
plt.show()

# %% [markdown]
# The mean and standard deviation for the stock prices data is the initial price and monthly volatility.

# %%
payoff = np.zeros((num,))
barrier = 35
strike = 70
for i in range(num):
    knocked_down = False
    for j in range(N+1):
        if prices[i][j] < barrier:
            knocked_down = True
            payoff[i] = 0
            break
    if knocked_down is False:
        payoff[i] = max(0,strike-prices[i][N])

price_option = np.average(payoff)*np.exp(-.1)
print("option price:", price_option)
# Out:
# option price: 13.170603372912074
